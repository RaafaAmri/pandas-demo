# %%
import pandas as pd

# %%
new_df=pd.read_csv('survey_results_public.csv')
new_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
new_df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...                            WelcomeChange  \
# ...

# %%
#let's filter ower dataframe to get people with age < 22
young_Emp=(df['Age'] < 22)
df_yEmp=new_df.loc[young_Emp,'MainBranch':'SurveyEase']
df_yEmp.head(3)
# Out:
#                                 MainBranch Hobbyist              OpenSourcer  \
# 0   I am a student who is learning to code      Yes                    Never
# 1   I am a student who is learning to code       No  Less than once per year
# 11  I am a student who is learning to code       No                    Never
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# 1   The quality of OSS and closed source software ...
# 11  OSS is, on average, of HIGHER quality than pro...
#
#                                 Employment                 Country  \
# 0   Not employed, and not looking for work          United Kingdom
# 1       Not employed, but looking for work  Bosnia and Herzegovina
# 11                      Employed part-time                  Canada
#
#            Student                                            EdLevel  \
# 0               No                          Primary/elementary school
# ...

# %%
#get the users from countries in the Variable Countries
Countries=['United State', 'United kingdom','Germany','Canada']
Country_filt=(df['Country'].isin(Countries))
df.loc[Country_filt,'Respondent':'Country']
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 11             12             I am a student who is learning to code       No
# 13             14                     I am a developer by profession      Yes
# 20             21                        I code primarily as a hobby      Yes
# 30             31             I am a student who is learning to code       No
# ...           ...                                                ...      ...
# 88829       80319                                                NaN      Yes
# 88838       82007                                                NaN       No
# 88850       83786                                                NaN       No
# 88855       85182                                                NaN       No
# 88878       88377                                                NaN      Yes
#
# ...

# %%
#filter the content wich contain "developers"
devoloper=(df['SONewContent'].str.contains('developers',na=False)) #na=False to avoid the "Nan"
df.loc[devoloper,'SONewContent']
# Out:
# 0        Tech articles written by other developers;Indu...
# 1        Tech articles written by other developers;Indu...
# 3        Tech articles written by other developers;Indu...
# 5        Tech articles written by other developers;Indu...
# 7        Tech articles written by other developers;Indu...
#                                ...
# 88870    Tech articles written by other developers;Indu...
# 88871    Tech articles written by other developers;Tech...
# 88876    Tech articles written by other developers;Indu...
# 88878    Tech articles written by other developers;Tech...
# 88882    Tech articles written by other developers;Indu...
# Name: SONewContent, Length: 51986, dtype: object

# %%
#we define another dataframe to work with
df=pd.read_csv('MOCK_DATA.csv',index_col='id')
df
# Out:
#      first_name  last_name                            email  gender  \
# id
# 1         Pearl     Ennals               pennals0@google.ru  Female
# 2         Nigel    Kelland               nkelland1@1688.com    Male
# 3       Rolando    Gammage             rgammage2@dyndns.org    Male
# 4        Cullen      Hamon            chamon3@cafepress.com    Male
# 5        Caesar    Raggitt        craggitt4@kickstarter.com    Male
# ...         ...        ...                              ...     ...
# 996      Prisca  Ellington            pellingtonrn@ehow.com  Female
# 997   Rosalinda       Grut          rgrutro@squarespace.com  Female
# 998    Melantha    Haldane               mhaldanerp@ftc.gov  Female
# 999      Hilton   Marzelle  hmarzellerq@creativecommons.org    Male
# 1000    Lisetta     Shoard               lshoardrr@time.com  Female
#
#           ip_address
# id
# 1       254.38.75.30
# 2       59.136.94.67
# 3      251.16.66.148
# 4       45.28.192.77
# 5       97.16.70.243
# ...

# %%
#filter the people with gender is female
female =(df['gender']=='Female')
new_df=df.loc[female, ['first_name','last_name','email','gender']]
new_df.head(8)
# Out:
#    first_name   last_name                     email  gender
# id
# 1       Pearl      Ennals        pennals0@google.ru  Female
# 7       Gerti     Quinell       gquinell6@youku.com  Female
# 8      Carlye   Constanza    cconstanza7@census.gov  Female
# 12     Oneida        Moss        omossb@behance.net  Female
# 16       Lacy   Krikorian  lkrikorianf@stanford.edu  Female
# 17       Sula  Bellhanger       sbellhangerg@si.edu  Female
# 18     Belita    Truscott    btruscotth@booking.com  Female
# 20      Beryl      McCurt         bmccurtj@xing.com  Female

# %%
#find the person with the firstname=Gerti
filt= (df['first_name']=='Gerti')
filt_df=df.loc[filt,'first_name':'ip_address']
filt_df
# Out:
#    first_name last_name                email  gender     ip_address
# id
# 7       Gerti   Quinell  gquinell6@youku.com  Female  18.121.106.31
