# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # 'None' mean that we want to display all rows and columns, 
pd.set_option('display.max_rows', None) #we can specify the number we want to display

# %%
#read the csv file and specify the id as an index
df=pd.read_csv('MOCK_DATA.csv',index_col='id')
df
# Out:
#      first_name  last_name                            email  gender  \
# id
# 1         Pearl     Ennals               pennals0@google.ru  Female
# 2         Nigel    Kelland               nkelland1@1688.com    Male
# 3       Rolando    Gammage             rgammage2@dyndns.org    Male
# 4        Cullen      Hamon            chamon3@cafepress.com    Male
# 5        Caesar    Raggitt        craggitt4@kickstarter.com    Male
# ...         ...        ...                              ...     ...
# 996      Prisca  Ellington            pellingtonrn@ehow.com  Female
# 997   Rosalinda       Grut          rgrutro@squarespace.com  Female
# 998    Melantha    Haldane               mhaldanerp@ftc.gov  Female
# 999      Hilton   Marzelle  hmarzellerq@creativecommons.org    Male
# 1000    Lisetta     Shoard               lshoardrr@time.com  Female
#
#           ip_address
# id
# 1       254.38.75.30
# 2       59.136.94.67
# 3      251.16.66.148
# 4       45.28.192.77
# 5       97.16.70.243
# ...

# %%
#return the columns in our dataframe
df.columns
# Out:
# Index(['first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
#by default the head fuction display the first 5 rows, and we can specify the number into the brackets 
df.head(10)
# Out:
#    first_name  last_name                      email  gender       ip_address
# id
# 1       Pearl     Ennals         pennals0@google.ru  Female     254.38.75.30
# 2       Nigel    Kelland         nkelland1@1688.com    Male     59.136.94.67
# 3     Rolando    Gammage       rgammage2@dyndns.org    Male    251.16.66.148
# 4      Cullen      Hamon      chamon3@cafepress.com    Male     45.28.192.77
# 5      Caesar    Raggitt  craggitt4@kickstarter.com    Male     97.16.70.243
# 6        Jeff   Rosiello      jrosiello5@drupal.org    Male    63.106.205.87
# 7       Gerti    Quinell        gquinell6@youku.com  Female    18.121.106.31
# 8      Carlye  Constanza     cconstanza7@census.gov  Female  102.166.197.235
# 9       Hazel      Olden       holden8@netvibes.com    Male    219.53.144.66
# 10     Wolfie     Cantor      wcantor9@japanpost.jp    Male   108.251.205.65

# %%
#by default display the last 5 rows, and we can specify the number into the brackets 
df.tail(2)
# Out:
#      first_name last_name                            email  gender  \
# id
# 999      Hilton  Marzelle  hmarzellerq@creativecommons.org    Male
# 1000    Lisetta    Shoard               lshoardrr@time.com  Female
#
#           ip_address
# id
# 999   119.12.216.126
# 1000   91.45.172.114

# %%
#return the dimension of the DataFrame
df.shape
# Out:
# (1000, 5)

# %%
#display a specific column exemple 'last_name'
df['last_name']
# Out:
# id
# 1         Ennals
# 2        Kelland
#           ...
# 999     Marzelle
# 1000      Shoard
# Name: last_name, Length: 1000, dtype: object

# %%
#loc is used to specify both row and column with label
#in this exemple we want to display the row number 2 
df.loc[2]
# Out:
# first_name           Nigel
# last_name          Kelland
#                   ...
# gender                Male
# ip_address    59.136.94.67
# Name: 2, Length: 5, dtype: object

# %%
#display rows from row 1 to row 10 
df.loc[1:10]
# Out:
#    first_name last_name  ...  gender      ip_address
# id                       ...
# 1       Pearl    Ennals  ...  Female    254.38.75.30
# 2       Nigel   Kelland  ...    Male    59.136.94.67
# ..        ...       ...  ...     ...             ...
# 9       Hazel     Olden  ...    Male   219.53.144.66
# 10     Wolfie    Cantor  ...    Male  108.251.205.65
#
# [10 rows x 5 columns]

# %%
#also we can specifiy wich column we want to display, in this exemple we want to display cols from emailt to ip_address
df.loc[1:10,'email':'ip_address']
# Out:
#                     email  gender      ip_address
# id
# 1      pennals0@google.ru  Female    254.38.75.30
# 2      nkelland1@1688.com    Male    59.136.94.67
# ..                    ...     ...             ...
# 9    holden8@netvibes.com    Male   219.53.144.66
# 10  wcantor9@japanpost.jp    Male  108.251.205.65
#
# [10 rows x 3 columns]

# %%
#to access multiple lines use double brackets separated by commas and specify the labels
df [['email', 'gender']]
df.head(15)
# Out:
#    first_name    last_name                        email  gender  \
# id
# 1       Pearl       Ennals           pennals0@google.ru  Female
# 2       Nigel      Kelland           nkelland1@1688.com    Male
# 3     Rolando      Gammage         rgammage2@dyndns.org    Male
# 4      Cullen        Hamon        chamon3@cafepress.com    Male
# 5      Caesar      Raggitt    craggitt4@kickstarter.com    Male
# 6        Jeff     Rosiello        jrosiello5@drupal.org    Male
# 7       Gerti      Quinell          gquinell6@youku.com  Female
# 8      Carlye    Constanza       cconstanza7@census.gov  Female
# 9       Hazel        Olden         holden8@netvibes.com    Male
# 10     Wolfie       Cantor        wcantor9@japanpost.jp    Male
# 11      Eldin      Allnutt  eallnutta@sciencedirect.com    Male
# 12     Oneida         Moss           omossb@behance.net  Female
# 13    Tiebold     Dressell    tdressellc@washington.edu    Male
# 14    Olivero      Worvill         oworvilld@senate.gov    Male
# ...

# %%
#iloc ollows to access row by location (position)
df.iloc[1]
# Out:
# first_name           Nigel
# last_name          Kelland
#                   ...
# gender                Male
# ip_address    59.136.94.67
# Name: 2, Length: 5, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    first_name last_name  ...  gender    ip_address
# id                       ...
# 1       Pearl    Ennals  ...  Female  254.38.75.30
# 2       Nigel   Kelland  ...    Male  59.136.94.67
#
# [2 rows x 5 columns]

# %%
#we can separate rows and coloumns with the double brakets, the first brakets[0,1] means rows with index 0 and 1, 
#then the column with index 1 wich is 'last name'
df.iloc[[0,1],1]
# Out:
# id
# 1     Ennals
# 2    Kelland
# Name: last_name, dtype: object

# %%
#here we can get the same result by using loc[] with labels 
df.loc[0:2,'last_name']
# Out:
# id
# 1     Ennals
# 2    Kelland
# Name: last_name, dtype: object

# %%
#Reset the index of the DataFrame wich is the id , and use the default one instead.
df.reset_index(inplace=True)

# %%
df.loc[[0,1,2], ['last_name','gender']]
# Out:
#   last_name  gender
# 0    Ennals  Female
# 1   Kelland    Male
# 2   Gammage    Male

# %%
#Sort the index descending
df.sort_index(ascending=False)
# Out:
#        id first_name  ...  gender      ip_address
# 999  1000    Lisetta  ...  Female   91.45.172.114
# 998   999     Hilton  ...    Male  119.12.216.126
# ..    ...        ...  ...     ...             ...
# 1       2      Nigel  ...    Male    59.136.94.67
# 0       1      Pearl  ...  Female    254.38.75.30
#
# [1000 rows x 6 columns]

# %%
#set the column headers to uppercase
df.columns=[x.upper() for x in df.columns]
df.head()
# Out:
#     ID FIRST_NAME  ...  GENDER    IP_ADDRESS
# 0    1      Pearl  ...  Female  254.38.75.30
# 1    2      Nigel  ...    Male  59.136.94.67
# ..  ..        ...  ...     ...           ...
# 3    4     Cullen  ...    Male  45.28.192.77
# 4    5     Caesar  ...    Male  97.16.70.243
#
# [5 rows x 6 columns]

# %%
#set the column headers to lowercase
df.columns=[x.lower() for x in df.columns]
df.head()
# Out:
#     id first_name  ...  gender    ip_address
# 0    1      Pearl  ...  Female  254.38.75.30
# 1    2      Nigel  ...    Male  59.136.94.67
# ..  ..        ...  ...     ...           ...
# 3    4     Cullen  ...    Male  45.28.192.77
# 4    5     Caesar  ...    Male  97.16.70.243
#
# [5 rows x 6 columns]
